# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [07:57, 65.7KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)    #预处理函数将任何标点符号改为其他标记, 因此句点被更改为 <PERIOD>。
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))   #输出单词总数
print("Unique words: {}".format(len(set(words))))   #输出不重复单词数量
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)    #create_lookup_tables函数将单词转为整数或者将证书转为单词
int_words = [vocab_to_int[word] for word in words]
print(int_words[:20])
# Out:
# [5238, 3081, 11, 5, 194, 1, 3135, 45, 58, 155, 127, 741, 476, 10605, 133, 0, 27519, 1, 0, 102]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import random
from collections import Counter
#导入计数器
threshold = 1e-5
word_counter = Counter(int_words)       #统计各单词出现的频数
total_counter = len(int_words)   #统计单词出现的总频数
freqs = {word : count/total_counter for word,count in word_counter.items()}      #计算各单词出现的频率
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counter}    #利用上述公式实现抽样
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1,window_size+1)    #利用np.random.randint随机初始化一个R
    start = 0
    if idx - R > 0:    #如果单词数组下标>随机数R，则窗口起始位置为：
        start = idx - R
    else:
        start = 0     #否则为0
    stop = idx + R    #窗口结束位置
    target_words = set(words[start:idx]+words[idx+1:stop+1])     #窗口包含的单词集合，剔除重复单词
    return target_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size    #计算每个batch_size的大小
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))    #这里为何要用extend?
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None],name='inputs')
    labels = tf.placeholder(tf.int32,[None,None],name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab) #单词数量
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding),-1,1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100     #样本数量
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab,n_embedding),stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,labels,embed,n_sampled,n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6687 0.3366 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6179 0.3264 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5207 0.3162 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5930 0.3161 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5076 0.3168 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5407 0.3151 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5391 0.3171 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5695 0.3155 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4717 0.3187 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4384 0.3191 sec/batch
# Nearest to and: gambler, hungary, ivar, tribal, saskatchewan, waived, solitude, entrepreneurs,
# Nearest to over: maguey, rumor, cira, rood, burma, inukshuk, investigate, calculi,
# Nearest to when: qianlong, so, chips, erodes, waist, deterred, owning, loins,
# Nearest to more: greyish, honorific, under, masterfully, mandrakes, mkultra, hurricane, venetian,
# Nearest to have: health, hazzard, regards, kabbalistic, discord, eastbourne, generation, mmm,
# Nearest to into: witnessing, cienfuegos, columbus, cuauht, solent, aussie, peacefully, parris,
# Nearest to th: lefty, lozada, woodpecker, clipper, jug, halland, skips, ruled,
# Nearest to on: news, kierkegaard, ap, polymers, disturbances, mellotron, majestic, corning,
# Nearest to governor: reductions, popularised, andreini, pius, twa, dreyfus, zoroastrianism, captors,
# Nearest to operations: thus, general, marrakech, stalled, intercalary, eclipse, strive, prizren,
# Nearest to assembly: languedoc, serbs, frontman, consistent, selassie, innovate, shots, aphra,
# Nearest to gold: herv, cobb, olbers, lindisfarne, imperatoribus, chairmen, levitt, granada,
# Nearest to channel: posterity, macdowell, apparently, henchmen, camilo, festival, miya, zvi,
# Nearest to issue: unreachable, sergius, microeconomic, physica, falkner, coolant, akademie, jurchen,
# Nearest to operating: sopranos, literate, idiosyncrasies, outselling, ucayali, neck, somebody, condensate,
# Nearest to bill: rias, slanted, maurizio, leap, subtler, maleficarum, ceuta, dysphoria,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4627 0.3281 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3445 0.3202 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3080 0.3189 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2353 0.3189 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1475 0.3197 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1742 0.3206 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0953 0.3203 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0571 0.3217 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9979 0.3241 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9798 0.3236 sec/batch
# Nearest to and: gambler, hungary, saskatchewan, tribal, entrepreneurs, ivar, west, data,
# Nearest to over: rumor, maguey, cira, rood, governmental, burma, visited, authoritative,
# Nearest to when: so, chips, qianlong, waist, erodes, owning, program, gets,
# Nearest to more: under, seen, neither, abandoned, greyish, roll, hurricane, honorific,
# Nearest to have: health, generation, regards, fishing, actively, lies, kabbalistic, kid,
# Nearest to into: witnessing, columbus, around, cienfuegos, monitor, peacefully, cuauht, directive,
# Nearest to th: ruled, jug, lefty, genetic, skips, halland, clipper, nicolo,
# Nearest to on: news, kierkegaard, senses, genocide, afford, dominant, ap, baron,
# Nearest to governor: reductions, popularised, reserve, ban, earnings, pius, current, twa,
# Nearest to operations: thus, general, strive, transactions, stalled, mahesh, overloaded, stabilized,
# Nearest to assembly: languedoc, consistent, shots, frontman, serbs, et, australia, colon,
# Nearest to gold: herv, named, cobb, granada, item, chairmen, imperatoribus, evolutionary,
# Nearest to channel: festival, apparently, posterity, usa, enforcement, specialized, twice, camilo,
# Nearest to issue: modified, maurizio, refusal, testament, walker, coolant, falkner, naming,
# Nearest to operating: literate, somebody, sopranos, henry, bigger, neck, declares, outselling,
# Nearest to bill: slanted, rias, leap, origin, maurizio, firing, subtler, seen,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9286 0.3308 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8794 5.8928 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8832 0.4088 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8563 7.3569 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8198 0.3181 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7833 0.3090 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8097 0.3055 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7837 0.3074 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7823 0.3090 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8010 0.3092 sec/batch
# Nearest to and: hungary, gambler, solitude, tribal, ridges, saskatchewan, ivar, holocaust,
# Nearest to over: maguey, visited, rumor, margin, cira, burma, governmental, inukshuk,
# Nearest to when: so, chips, qianlong, owning, erodes, deterred, waist, frontier,
# Nearest to more: hurricane, under, denoting, seen, sounding, honorific, poses, additions,
# Nearest to have: health, generation, regards, kabbalistic, eastbourne, ve, fishing, vav,
# Nearest to into: witnessing, columbus, cienfuegos, monitor, sharers, around, mortal, aussie,
# Nearest to th: lefty, worst, jug, pegged, halland, ruled, skips, clipper,
# Nearest to on: news, ap, sleeve, kierkegaard, essays, select, prominently, tacitly,
# Nearest to governor: reductions, popularised, ban, reserve, minded, earnings, inseparable, zoroastrianism,
# Nearest to operations: thus, general, stalled, strive, transactions, stabilized, eclipse, latent,
# Nearest to assembly: languedoc, consistent, serbs, et, frontman, shots, latium, colon,
# Nearest to gold: herv, named, cobb, granada, observers, imperatoribus, olbers, chairmen,
# Nearest to channel: festival, usa, apparently, posterity, miya, mild, specialized, twice,
# Nearest to issue: modified, ptolemy, coolant, misguided, physica, refusal, walker, thousand,
# Nearest to operating: literate, henry, somebody, sopranos, idiosyncrasies, bigger, neck, tectonic,
# Nearest to bill: rias, slanted, leap, origin, ferry, statutes, maurizio, intelligent,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7740 0.3148 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7621 0.3090 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7112 0.3108 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6973 0.3090 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7478 0.3154 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7007 0.3111 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6912 0.3131 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7179 0.3113 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7119 0.3148 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6673 0.3102 sec/batch
# Nearest to and: hungary, gambler, holocaust, waived, ridges, solitude, saskatchewan, freshwater,
# Nearest to over: margin, maguey, visited, cira, rumor, burma, inukshuk, bosnians,
# Nearest to when: so, qianlong, chips, owning, deterred, waist, erodes, bounded,
# Nearest to more: honorific, hurricane, poses, seen, denoting, sounding, additions, under,
# Nearest to have: health, eastbourne, regards, ve, kabbalistic, generation, actively, vav,
# Nearest to into: witnessing, columbus, sharers, mortal, cienfuegos, solent, around, cuauht,
# Nearest to th: lefty, worst, jug, woodpecker, halland, skips, pegged, clipper,
# Nearest to on: news, ap, mellotron, sleeve, protections, brigid, select, tacitly,
# Nearest to governor: reductions, popularised, ban, minded, inseparable, liam, harms, clutches,
# Nearest to operations: thus, stalled, general, strive, ribbentrop, eclipse, transactions, fidelity,
# Nearest to assembly: languedoc, serbs, frontman, consistent, et, latium, colon, constituents,
# Nearest to gold: herv, imperatoribus, cobb, olbers, named, granada, chairmen, observers,
# Nearest to channel: festival, usa, posterity, mild, apparently, miya, chapter, camilo,
# Nearest to issue: microeconomic, modified, ptolemy, coolant, physica, anglicans, walker, misguided,
# Nearest to operating: literate, sopranos, idiosyncrasies, somebody, hermeticism, razed, tectonic, outselling,
# Nearest to bill: rias, slanted, leap, ceuta, statutes, maurizio, deuce, foreshadowing,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6738 0.3127 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6744 0.3134 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6088 0.3139 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6294 0.3084 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6321 0.3195 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6261 5.9694 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6118 5.9009 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5317 5.9037 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5225 0.4018 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5007 5.9853 sec/batch
# Nearest to and: ridges, hungary, gambler, waived, solitude, ivar, holocaust, saskatchewan,
# Nearest to over: margin, visited, cira, bosnians, maguey, grosse, burma, malthusian,
# Nearest to when: so, chips, qianlong, owning, cursive, deterred, waist, erodes,
# Nearest to more: honorific, seen, denoting, poses, masterfully, sounding, hurricane, additions,
# Nearest to have: health, eastbourne, regards, kabbalistic, vav, actively, perpetuation, classify,
# Nearest to into: witnessing, sharers, around, cienfuegos, cuauht, columbus, ainu, aussie,
# Nearest to th: lefty, nicolo, halland, worst, orientalist, skips, ruled, woodpecker,
# Nearest to on: news, ap, mellotron, sleeve, brigid, lachaise, prominently, select,
# Nearest to governor: popularised, ban, reductions, harms, tty, inseparable, clutches, austrians,
# Nearest to operations: thus, stalled, eclipse, marrakech, fidelity, general, transactions, ribbentrop,
# Nearest to assembly: languedoc, serbs, frontman, innovate, latium, consistent, buryat, constituents,
# Nearest to gold: herv, imperatoribus, olbers, cobb, granada, feathers, named, lindisfarne,
# Nearest to channel: festival, usa, mild, miya, posterity, camilo, zvi, guiscard,
# Nearest to issue: microeconomic, coolant, misguided, unreachable, ameliorated, anglicans, thousand, physica,
# Nearest to operating: unix, idiosyncrasies, literate, systems, whale, hermeticism, bigger, outselling,
# Nearest to bill: rias, slanted, ceuta, maleficarum, kanons, leap, deuce, foreshadowing,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5098 1.7669 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5298 0.3268 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4556 0.3534 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5443 0.3429 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4936 0.3530 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4882 0.3513 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4379 0.3716 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4079 0.3726 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4321 0.3740 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4109 0.3472 sec/batch
# Nearest to and: ridges, waived, ivar, freshwater, gambler, solitude, hungary, punctuation,
# Nearest to over: margin, cira, visited, bosnians, maguey, malthusian, grosse, undercoat,
# Nearest to when: so, chips, owning, deterred, qianlong, cursive, erodes, gets,
# Nearest to more: honorific, denoting, seen, sounding, poses, masterfully, additions, strategies,
# Nearest to have: health, eastbourne, regards, perpetuation, kabbalistic, figurative, actively, generation,
# Nearest to into: witnessing, around, sharers, aeschylus, cuauht, cienfuegos, ainu, aussie,
# Nearest to th: lefty, ruled, nicolo, halland, skips, orientalist, pegged, oddparents,
# Nearest to on: news, mellotron, ap, jaffa, protections, sleeve, brigid, mais,
# Nearest to governor: popularised, ban, reductions, harms, liam, hoss, tty, snegur,
# Nearest to operations: thus, transactions, eclipse, fidelity, marrakech, general, stalled, halfbakery,
# Nearest to assembly: serbs, frontman, languedoc, elected, parliament, election, innovate, golconda,
# Nearest to gold: herv, imperatoribus, olbers, cobb, feathers, named, mujahedeen, milken,
# Nearest to channel: festival, usa, mild, posterity, miya, camilo, reintroducing, twice,
# Nearest to issue: microeconomic, ameliorated, unreachable, refusal, ptolemy, coolant, misguided, maurizio,
# Nearest to operating: unix, systems, generates, outselling, idiosyncrasies, literate, whale, aiken,
# Nearest to bill: rias, slanted, deuce, boston, kanons, ceuta, maleficarum, leap,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4435 0.3878 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4279 0.3473 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4298 0.3395 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4132 0.3643 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3942 0.3092 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4710 0.3126 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3837 0.3475 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3499 0.3593 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4111 0.3375 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3368 0.3357 sec/batch
# Nearest to and: ivar, waived, solitude, ridges, freshwater, gambler, hungary, proportion,
# Nearest to over: margin, maguey, undercoat, cira, bosnians, malthusian, dieting, cpes,
# Nearest to when: so, chips, gets, owning, qianlong, erodes, deterred, cursive,
# Nearest to more: honorific, denoting, seen, strategies, poses, lecter, sounding, hold,
# Nearest to have: health, eastbourne, regards, perpetuation, generation, figurative, symptoms, classify,
# Nearest to into: witnessing, around, sharers, aeschylus, ainu, cienfuegos, furtherance, aussie,
# Nearest to th: lefty, halland, orientalist, ruled, pegged, ancient, nicolo, jug,
# Nearest to on: news, ap, mellotron, sleeve, prominently, dialog, perched, jaffa,
# Nearest to governor: popularised, ban, hoss, snegur, harms, coburg, pius, liam,
# Nearest to operations: thus, transactions, general, marrakech, halfbakery, fidelity, eclipse, stalled,
# Nearest to assembly: elected, serbs, parliament, pluriform, election, languedoc, frontman, legislative,
# Nearest to gold: herv, imperatoribus, olbers, named, cobb, mujahedeen, milken, contractile,
# Nearest to channel: festival, usa, mild, camilo, guiscard, catchment, reintroducing, posterity,
# Nearest to issue: microeconomic, ameliorated, refusal, unreachable, ptolemy, akademie, physica, coolant,
# Nearest to operating: unix, generates, systems, outselling, literate, idiosyncrasies, peripherals, switches,
# Nearest to bill: slanted, rias, maleficarum, deuce, boston, kanons, kaspar, manger,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3767 0.3389 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4039 0.3437 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3590 0.3327 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3436 0.3414 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4070 0.3535 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3508 0.3473 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3770 0.3341 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4018 0.3179 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3333 0.3274 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3398 0.3659 sec/batch
# Nearest to and: ivar, hungary, adapt, proportion, waived, ridges, saskatchewan, freshwater,
# Nearest to over: margin, undercoat, bosnians, maguey, cira, prefecture, malthusian, cpes,
# Nearest to when: so, gets, chips, owning, qianlong, erodes, deterred, waist,
# Nearest to more: honorific, sounding, denoting, strategies, gestalt, lecter, poses, periodically,
# Nearest to have: eastbourne, health, regards, perpetuation, couples, classify, generation, kabbalistic,
# Nearest to into: witnessing, around, sharers, aeschylus, cienfuegos, erectus, ainu, relegating,
# Nearest to th: halland, ancient, lefty, pegged, ruled, orientalist, byzantine, nicolo,
# Nearest to on: news, ap, mellotron, sleeve, s, lachaise, orloff, dialog,
# Nearest to governor: popularised, liam, hoss, snegur, ban, pius, coburg, austrians,
# Nearest to operations: general, thus, transactions, marrakech, fidelity, eclipse, halfbakery, ribbentrop,
# Nearest to assembly: pluriform, elected, parliament, serbs, legislative, election, frontman, languedoc,
# Nearest to gold: imperatoribus, herv, olbers, named, cobb, feathers, lindisfarne, milken,
# Nearest to channel: festival, usa, mild, camilo, catchment, varnish, corporation, guiscard,
# Nearest to issue: microeconomic, refusal, ameliorated, appeal, maurizio, coolant, akademie, unreachable,
# Nearest to operating: unix, systems, competitors, filenames, generates, outselling, peripherals, ds,
# Nearest to bill: rias, maleficarum, slanted, deuce, kanons, statutes, boston, ethicists,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3397 0.3535 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2814 0.3704 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3852 0.3082 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3666 0.3561 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3700 0.3101 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2741 0.3407 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3337 0.3224 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3452 0.3332 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2226 0.3359 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2976 0.3582 sec/batch
# Nearest to and: ivar, freshwater, hungary, proportion, adapt, saskatchewan, waived, magenta,
# Nearest to over: undercoat, margin, bosnians, maguey, cira, prefecture, burma, cpes,
# Nearest to when: so, gets, qianlong, erodes, chips, owning, cursive, waist,
# Nearest to more: honorific, sounding, seen, strategies, poses, long, hold, periodically,
# Nearest to have: eastbourne, regards, health, classify, couples, kabbalistic, perpetuation, generation,
# Nearest to into: witnessing, around, sharers, cienfuegos, aeschylus, monitor, erectus, relegating,
# Nearest to th: ancient, halland, ruled, byzantine, pegged, lefty, nd, nicolo,
# Nearest to on: news, ap, s, fannie, lachaise, sleeve, leacock, orloff,
# Nearest to governor: liam, hoss, snegur, popularised, ban, pius, coburg, hale,
# Nearest to operations: marrakech, general, thus, transactions, fidelity, eclipse, halfbakery, stalled,
# Nearest to assembly: pluriform, elected, parliament, election, serbs, legislative, constituencies, bicameral,
# Nearest to gold: imperatoribus, olbers, herv, named, feathers, cobb, milken, lindisfarne,
# Nearest to channel: festival, usa, mild, catchment, camilo, glendale, varnish, airlifter,
# Nearest to issue: microeconomic, refusal, lutenists, appeal, sergius, ameliorated, maurizio, akademie,
# Nearest to operating: unix, ported, competitors, filenames, systems, outselling, peripherals, literate,
# Nearest to bill: maleficarum, deuce, boston, rias, kanons, andrew, ethicists, slanted,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3037 0.3514 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3235 0.3430 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3091 0.1542 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2408 0.3783 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2067 0.3420 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2161 0.3309 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2226 0.3135 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2152 0.3153 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2079 0.3386 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1652 0.3429 sec/batch
# Nearest to and: freshwater, hungary, ivar, proportion, saskatchewan, adapt, librarianship, hare,
# Nearest to over: undercoat, margin, cpes, bosnians, widest, censuses, prefecture, mesozoic,
# Nearest to when: so, gets, qianlong, waist, owning, erodes, chips, cursive,
# Nearest to more: honorific, seen, poses, long, sounding, gestalt, occident, strategies,
# Nearest to have: eastbourne, couples, regards, health, kabbalistic, classify, generation, perpetuation,
# Nearest to into: witnessing, around, sharers, cienfuegos, erectus, aeschylus, relegating, theban,
# Nearest to th: ancient, halland, pegged, nd, ruled, byzantine, orientalist, preslav,
# Nearest to on: news, ap, s, jaffa, orloff, lothian, lachaise, perched,
# Nearest to governor: liam, snegur, pius, hoss, hale, reserve, reductions, popularised,
# Nearest to operations: general, marrakech, transactions, thus, eclipse, halfbakery, fidelity, stalled,
# Nearest to assembly: pluriform, elected, legislative, bicameral, election, constituencies, parliament, serbs,
# Nearest to gold: imperatoribus, herv, olbers, feathers, named, milken, lindisfarne, metals,
# Nearest to channel: usa, festival, catchment, camilo, glendale, varnish, corporation, vignettes,
# Nearest to issue: microeconomic, refusal, ameliorated, lutenists, appeal, sergius, coolant, physica,
# Nearest to operating: unix, competitors, ported, vcs, peripherals, systems, disk, generates,
# Nearest to bill: maleficarum, rias, kanons, deuce, statutes, andrew, boston, slanted,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2365 0.3412 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2216 0.3538 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2304 0.3423 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1235 0.3322 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1619 0.3351 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1699 0.3344 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1531 0.3411 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1854 0.3402 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1869 0.3506 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1742 0.3693 sec/batch
# Nearest to and: freshwater, ivar, proportion, saskatchewan, librarianship, magenta, adapt, hungary,
# Nearest to over: undercoat, margin, cpes, overtime, widest, maguey, cira, bosnians,
# Nearest to when: so, waist, gets, chips, owning, qianlong, erodes, cursive,
# Nearest to more: poses, sounding, strategies, long, additions, rotated, honorific, seen,
# Nearest to have: eastbourne, couples, perpetuation, regards, generation, classify, energize, mmm,
# Nearest to into: witnessing, around, sharers, monitor, condensed, cienfuegos, relegating, erectus,
# Nearest to th: ancient, halland, nd, pegged, preslav, ruled, lefty, byzantine,
# Nearest to on: news, ap, perched, s, sleeve, timestamping, orloff, notting,
# Nearest to governor: liam, reserve, snegur, hoss, pius, ban, reductions, hale,
# Nearest to operations: general, marrakech, transactions, halfbakery, stalled, thus, eclipse, supervision,
# Nearest to assembly: pluriform, elected, legislative, bicameral, election, constituencies, representatives, serbs,
# Nearest to gold: olbers, imperatoribus, herv, metals, feathers, named, milken, precipitates,
# Nearest to channel: festival, usa, camilo, catchment, glendale, widebody, ahimelech, airlifter,
# Nearest to issue: microeconomic, ameliorated, refusal, lutenists, appeal, unreachable, physica, coolant,
# Nearest to operating: unix, peripherals, vcs, competitors, outselling, generates, disk, ported,
# Nearest to bill: maleficarum, rias, boston, deuce, kanons, slanted, andrew, statutes,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1755 0.3532 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2409 0.3281 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1679 0.3237 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1784 0.3214 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1720 0.3268 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1740 0.3265 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2056 0.3263 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1621 0.3273 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1389 0.3239 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1921 0.3226 sec/batch
# Nearest to and: ivar, facilitates, librarianship, adapt, saskatchewan, zeroes, waived, proportion,
# Nearest to over: undercoat, margin, overtime, cpes, widest, bosnians, censuses, maguey,
# Nearest to when: so, waist, chips, gets, erodes, owning, qianlong, deterred,
# Nearest to more: sounding, poses, strategies, rotated, long, occident, dirkjan, denoting,
# Nearest to have: eastbourne, couples, generation, perpetuation, mmm, regards, kabbalistic, energize,
# Nearest to into: witnessing, around, sharers, cienfuegos, monitor, glossed, condensed, theban,
# Nearest to th: nd, halland, preslav, ancient, pegged, lefty, estelle, byzantine,
# Nearest to on: news, ap, s, notting, perched, sleeve, massively, timestamping,
# Nearest to governor: liam, reserve, snegur, hoss, pius, hale, coburg, pluriform,
# Nearest to operations: general, marrakech, transactions, thus, halfbakery, supervision, eclipse, stalled,
# Nearest to assembly: pluriform, elected, constituencies, election, legislative, bicameral, representatives, serbs,
# Nearest to gold: olbers, imperatoribus, herv, metals, named, feathers, milken, precipitates,
# Nearest to channel: usa, festival, camilo, catchment, ahimelech, glendale, bbc, sledge,
# Nearest to issue: microeconomic, refusal, ameliorated, lutenists, sergius, appeal, unreachable, maurizio,
# Nearest to operating: unix, vcs, peripherals, competitors, outselling, ported, generates, minix,
# Nearest to bill: maleficarum, statutes, rias, deuce, kanons, punched, brash, lawsuit,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1925 0.3274 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1803 0.3239 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1555 0.3253 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1746 0.3328 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1425 0.3462 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1578 0.3390 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1645 0.3517 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1421 0.3620 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1768 0.3267 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2135 0.3272 sec/batch
# Nearest to and: saskatchewan, ivar, steve, hungary, cadres, taganrog, adapt, caray,
# Nearest to over: undercoat, margin, cpes, overtime, algerians, prefecture, censuses, bosnians,
# Nearest to when: so, chips, qianlong, gets, waist, erodes, widows, owning,
# Nearest to more: sounding, poses, long, dirkjan, strategies, detach, archbishop, mechanized,
# Nearest to have: couples, eastbourne, regards, classify, generation, kabbalistic, perpetuation, mmm,
# Nearest to into: witnessing, around, sharers, cienfuegos, kane, monitor, theban, condensed,
# Nearest to th: nd, halland, preslav, ancient, byzantine, pegged, ruled, century,
# Nearest to on: news, s, ap, notting, asis, joaquim, fannie, orloff,
# Nearest to governor: liam, reserve, snegur, hale, hoss, reductions, pius, lieutenant,
# Nearest to operations: marrakech, general, halfbakery, thus, supervision, eclipse, transactions, stalled,
# Nearest to assembly: pluriform, elected, constituencies, legislative, bicameral, election, serbs, office,
# Nearest to gold: olbers, herv, imperatoribus, metals, milken, feathers, named, item,
# Nearest to channel: usa, festival, ahimelech, catchment, camilo, bbc, widebody, mulliken,
# Nearest to issue: microeconomic, ameliorated, refusal, lutenists, unreachable, maurizio, sergius, appeal,
# Nearest to operating: unix, vcs, competitors, outselling, peripherals, minix, ported, disk,
# Nearest to bill: maleficarum, statutes, andrew, kanons, punched, deuce, boston, brash,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2374 0.3747 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1768 0.3519 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1668 0.3321 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1683 0.3316 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0710 0.3502 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1144 0.3862 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1458 0.3440 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1379 0.3312 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1430 0.0629 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1216 0.3422 sec/batch
# Nearest to and: freshwater, facilitates, librarianship, magenta, proportion, zeroes, adapt, steve,
# Nearest to over: undercoat, margin, overtime, cpes, mortality, ids, censuses, algerians,
# Nearest to when: so, chips, waist, gets, qianlong, erodes, cursive, owning,
# Nearest to more: poses, long, strategies, detach, rotated, sounding, dirkjan, additions,
# Nearest to have: couples, eastbourne, generation, kabbalistic, classify, mmm, regards, perpetuation,
# Nearest to into: witnessing, around, sharers, monitor, condensed, theban, cienfuegos, erectus,
# Nearest to th: nd, ancient, halland, preslav, pegged, byzantine, century, legalization,
# Nearest to on: news, perched, s, asis, sleeve, ap, notting, joaquim,
# Nearest to governor: liam, reserve, snegur, lieutenant, pius, hale, pluriform, hoss,
# Nearest to operations: marrakech, general, eclipse, halfbakery, supervision, transactions, thus, armament,
# Nearest to assembly: pluriform, elected, bicameral, legislative, constituencies, election, office, serbs,
# Nearest to gold: olbers, metals, imperatoribus, herv, feathers, precipitates, item, milken,
# Nearest to channel: usa, festival, bbc, mulliken, widebody, catchment, ahimelech, glendale,
# Nearest to issue: microeconomic, ameliorated, refusal, maurizio, unreachable, lutenists, appeal, coolant,
# Nearest to operating: unix, vcs, competitors, peripherals, outselling, minix, ported, filenames,
# Nearest to bill: maleficarum, statutes, deuce, punched, kanons, lawsuit, andrew, brash,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0470 0.3618 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0682 0.3563 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0982 0.3374 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0444 0.3445 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0929 0.3341 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0557 0.3452 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1003 0.3240 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1004 0.3460 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1065 0.3487 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0447 0.3370 sec/batch
# Nearest to and: freshwater, librarianship, cadres, transformed, zeroes, adapt, tankers, facilitates,
# Nearest to over: undercoat, overtime, margin, cpes, algerians, mortality, ids, to,
# Nearest to when: so, chips, gets, waist, deterred, owning, erodes, qianlong,
# Nearest to more: long, detach, strategies, poses, sounding, hold, rotated, dirkjan,
# Nearest to have: couples, eastbourne, generation, other, homes, classify, regards, mmm,
# Nearest to into: witnessing, around, sharers, condensed, cienfuegos, erectus, monitor, aeschylus,
# Nearest to th: nd, preslav, century, ancient, pegged, halland, legalization, byzantine,
# Nearest to on: news, perched, sleeve, asis, s, notting, ap, joaquim,
# Nearest to governor: reserve, liam, snegur, reductions, pius, pluriform, lieutenant, hale,
# Nearest to operations: marrakech, general, eclipse, operation, halfbakery, siddeley, supervision, thus,
# Nearest to assembly: pluriform, elected, bicameral, office, constituencies, legislative, representatives, judiciary,
# Nearest to gold: olbers, metals, imperatoribus, herv, feathers, precipitates, item, titanium,
# Nearest to channel: usa, festival, bbc, vignettes, sledge, glendale, widebody, ahimelech,
# Nearest to issue: microeconomic, ameliorated, maurizio, appeal, refusal, lutenists, centripetal, coolant,
# Nearest to operating: vcs, outselling, swivel, competitors, unix, peripherals, minix, filenames,
# Nearest to bill: maleficarum, lawsuit, statutes, punched, deuce, andrew, rias, brash,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0057 0.3636 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0363 0.3500 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0080 0.3410 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0493 0.3613 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0715 0.3807 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0557 0.3636 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0422 0.3363 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1145 0.3298 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0543 0.3382 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0017 0.3356 sec/batch
# Nearest to and: librarianship, zeroes, facilitates, cadres, freshwater, transformed, proportion, saskatchewan,
# Nearest to over: undercoat, overtime, cpes, margin, mortality, ids, processor, to,
# Nearest to when: so, chips, gets, waist, erodes, cursive, puppet, owning,
# Nearest to more: poses, detach, strategies, long, dirkjan, sounding, rotated, hold,
# Nearest to have: couples, other, generation, eastbourne, mmm, are, homes, aranese,
# Nearest to into: witnessing, sharers, around, monitor, condensed, kane, ainu, cienfuegos,
# Nearest to th: nd, halland, preslav, century, legalization, estelle, ancient, woodpecker,
# Nearest to on: news, asis, sleeve, ap, joaquim, perched, orloff, kinsey,
# Nearest to governor: reserve, liam, snegur, lieutenant, pluriform, pius, hale, reductions,
# Nearest to operations: marrakech, general, thus, supervision, stalled, eclipse, halfbakery, transactions,
# Nearest to assembly: pluriform, elected, bicameral, constituencies, legislative, office, representatives, appointed,
# Nearest to gold: olbers, metals, herv, precipitates, imperatoribus, feathers, item, titanium,
# Nearest to channel: usa, festival, bbc, sledge, ahimelech, widebody, glendale, aired,
# Nearest to issue: microeconomic, ameliorated, refusal, unreachable, appeal, lutenists, answers, dlp,
# Nearest to operating: vcs, outselling, unix, minix, competitors, peripherals, disk, drivers,
# Nearest to bill: maleficarum, lawsuit, statutes, brash, andrew, punched, boston, deuce,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0489 0.3699 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0719 0.3577 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0985 0.3475 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0857 0.3334 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0958 0.3595 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0382 0.3370 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0833 0.3454 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0827 0.3850 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0788 0.3764 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0701 0.3532 sec/batch
# Nearest to and: cadres, librarianship, the, hungary, transformed, saskatchewan, constituting, in,
# Nearest to over: undercoat, cpes, margin, overtime, ids, processor, iix, ppr,
# Nearest to when: chips, so, gets, waist, erodes, deterred, puppet, qianlong,
# Nearest to more: detach, dirkjan, long, archbishop, livin, mechanized, sounding, poses,
# Nearest to have: couples, eastbourne, other, generation, mmm, are, households, homes,
# Nearest to into: witnessing, around, sharers, aeschylus, venetians, monitor, ainu, theban,
# Nearest to th: nd, century, preslav, halland, legalization, ancient, pegged, byzantine,
# Nearest to on: news, joaquim, asis, s, september, orloff, undertook, governorates,
# Nearest to governor: reserve, liam, pluriform, lieutenant, snegur, reductions, pius, hale,
# Nearest to operations: marrakech, general, thus, eclipse, siddeley, halfbakery, supervision, stalled,
# Nearest to assembly: pluriform, elected, bicameral, legislative, constituencies, constituents, judiciary, office,
# Nearest to gold: metals, olbers, precipitates, titanium, item, feathers, imperatoribus, herv,
# Nearest to channel: festival, bbc, widebody, sledge, glendale, usa, ahimelech, aired,
# Nearest to issue: microeconomic, ameliorated, sergius, refusal, appeal, maurizio, lutenists, answers,
# Nearest to operating: vcs, outselling, minix, unix, competitors, peripherals, filenames, disk,
# Nearest to bill: maleficarum, statutes, lawsuit, punched, andrew, worse, fen, slanted,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0343 0.3635 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0097 0.3523 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0367 0.3429 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0658 0.3435 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0704 0.3692 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1218 0.3612 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1107 0.3960 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0540 0.3719 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0560 0.3644 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0918 0.3425 sec/batch
# Nearest to and: cadres, transformed, proportion, facilitates, the, constituting, freshwater, librarianship,
# Nearest to over: undercoat, margin, cpes, overtime, ids, processor, algerians, ppr,
# Nearest to when: so, chips, gets, puppet, jtf, waist, cursive, lessened,
# Nearest to more: detach, poses, mechanized, dirkjan, sounding, strategies, long, tendency,
# Nearest to have: couples, eastbourne, other, mmm, households, aranese, generation, are,
# Nearest to into: witnessing, around, condensed, sharers, monitor, kane, mabo, ainu,
# Nearest to th: nd, century, legalization, preslav, halland, byzantine, earliest, stjepan,
# Nearest to on: news, joaquim, ap, perched, s, asis, orloff, september,
# Nearest to governor: liam, reserve, lieutenant, pluriform, snegur, hale, pius, reductions,
# Nearest to operations: marrakech, general, eclipse, supervision, operation, siddeley, thus, halfbakery,
# Nearest to assembly: pluriform, elected, constituents, bicameral, legislative, constituencies, office, taoiseach,
# Nearest to gold: metals, olbers, titanium, precipitates, item, imperatoribus, tin, feathers,
# Nearest to channel: bbc, ahimelech, sledge, widebody, glendale, festival, knowbot, usa,
# Nearest to issue: microeconomic, sergius, moulton, maurizio, ameliorated, refusal, appeal, feist,
# Nearest to operating: vcs, outselling, unix, minix, swivel, competitors, drivers, literate,
# Nearest to bill: maleficarum, statutes, punched, andrew, lawsuit, kanons, awaits, nutrition,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9802 0.3567 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0366 0.3680 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0654 0.3265 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0511 0.3311 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0973 0.3390 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0182 0.3314 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9771 0.3472 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9644 0.3234 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0114 0.3532 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9839 0.3445 sec/batch
# Nearest to and: transformed, cadres, librarianship, constituting, the, zeroes, proportion, verus,
# Nearest to over: undercoat, cpes, margin, ids, overtime, ppr, censuses, algerians,
# Nearest to when: so, chips, puppet, waist, gets, cursive, deterred, erodes,
# Nearest to more: detach, outliers, long, dirkjan, strategies, gestalt, mechanized, poses,
# Nearest to have: couples, other, eastbourne, are, mmm, households, homes, aranese,
# Nearest to into: witnessing, around, condensed, sharers, monitor, aeschylus, glossed, fragments,
# Nearest to th: nd, century, legalization, earliest, preslav, halland, byzantine, history,
# Nearest to on: news, joaquim, asis, ap, perched, orloff, smg, s,
# Nearest to governor: liam, reserve, lieutenant, pluriform, hale, reductions, snegur, pius,
# Nearest to operations: marrakech, siddeley, eclipse, general, supervision, operation, thus, halfbakery,
# Nearest to assembly: pluriform, constituents, constituencies, bicameral, elected, legislative, languedoc, office,
# Nearest to gold: metals, olbers, titanium, item, precipitates, feathers, imperatoribus, tin,
# Nearest to channel: sledge, widebody, knowbot, ahimelech, glendale, channels, bbc, telegram,
# Nearest to issue: microeconomic, sergius, ameliorated, moulton, maurizio, refusal, appeal, undone,
# Nearest to operating: vcs, minix, unix, outselling, swivel, competitors, disk, peripherals,
# Nearest to bill: maleficarum, statutes, punched, andrew, lawsuit, slanted, intelligent, nutrition,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0067 0.3569 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9703 0.3344 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0293 0.3462 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0216 0.3275 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0244 0.3408 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0220 0.3276 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9219 0.3458 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9397 0.3446 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9301 0.3429 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9782 0.3376 sec/batch
# Nearest to and: the, in, zeroes, are, cadres, transformed, librarianship, from,
# Nearest to over: undercoat, cpes, overtime, margin, algerians, ppr, ids, censuses,
# Nearest to when: so, chips, gets, waist, puppet, lessened, deterred, erodes,
# Nearest to more: mechanized, detach, long, poses, than, less, rotated, strategies,
# Nearest to have: couples, are, other, householder, households, aranese, homes, mmm,
# Nearest to into: witnessing, around, condensed, sharers, monitor, mabo, fragments, soul,
# Nearest to th: nd, century, legalization, earliest, history, preslav, halland, byzantine,
# Nearest to on: news, joaquim, the, perched, asis, sleeve, ap, prayers,
# Nearest to governor: reserve, liam, lieutenant, pluriform, reductions, hale, pius, snegur,
# Nearest to operations: marrakech, siddeley, operation, eclipse, supervision, general, thus, cascavel,
# Nearest to assembly: pluriform, constituents, bicameral, elected, constituencies, legislative, appointed, judiciary,
# Nearest to gold: metals, olbers, titanium, tin, item, precipitates, feathers, imperatoribus,
# Nearest to channel: bbc, sledge, aired, widebody, channels, ahimelech, tv, glendale,
# Nearest to issue: microeconomic, ameliorated, sergius, dlp, moulton, maurizio, undone, answers,
# Nearest to operating: vcs, minix, outselling, unix, swivel, disk, peripherals, filenames,
# Nearest to bill: maleficarum, punched, andrew, statutes, lawsuit, nutrition, bowen, intelligent,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0091 0.3341 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0033 0.3339 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9503 0.3470 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0288 0.3415 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0390 0.3571 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9441 0.3559 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0054 0.3686 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9956 0.3489 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0076 0.3367 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0084 0.3489 sec/batch
# Nearest to and: the, zeroes, in, cadres, are, librarianship, transformed, schickele,
# Nearest to over: undercoat, overtime, margin, cpes, ppr, censuses, algerians, total,
# Nearest to when: so, gets, chips, waist, erodes, puppet, cursive, castillian,
# Nearest to more: detach, outliers, additions, mechanized, archbishop, poses, than, long,
# Nearest to have: couples, other, are, generation, aranese, mmm, households, householder,
# Nearest to into: witnessing, condensed, around, sharers, soul, mabo, monitor, kane,
# Nearest to th: nd, century, legalization, estelle, history, preslav, halland, earliest,
# Nearest to on: news, joaquim, the, prayers, s, asis, hamlet, sleeve,
# Nearest to governor: liam, reserve, lieutenant, pluriform, pius, snegur, hale, reductions,
# Nearest to operations: marrakech, operation, supervision, siddeley, eclipse, general, thus, cascavel,
# Nearest to assembly: constituents, pluriform, elected, bicameral, constituencies, languedoc, legislative, selassie,
# Nearest to gold: olbers, metals, tin, titanium, herv, item, imperatoribus, feathers,
# Nearest to channel: channels, sledge, bbc, widebody, telegram, tv, estonia, festival,
# Nearest to issue: microeconomic, moulton, ameliorated, undone, sergius, dlp, maurizio, feist,
# Nearest to operating: vcs, minix, outselling, unix, swivel, drivers, systems, competitors,
# Nearest to bill: maleficarum, punched, statutes, andrew, lawsuit, nutrition, awaits, intelligent,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0127 0.3357 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9781 0.3363 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9988 0.3375 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9985 0.3293 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0051 0.3335 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9885 0.3616 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9742 0.3460 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9643 0.3530 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9982 0.3578 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0237 0.3499 sec/batch
# Nearest to and: the, in, of, zeroes, see, facilitates, cadres, transformed,
# Nearest to over: undercoat, cpes, margin, overtime, processor, bosnians, censuses, ppr,
# Nearest to when: so, chips, gets, lessened, deterred, puppet, waist, erodes,
# Nearest to more: detach, mechanized, long, tendency, strategies, less, gdansk, additions,
# Nearest to have: couples, other, are, aranese, exclusion, households, generation, urnfield,
# Nearest to into: witnessing, around, condensed, kane, sharers, mabo, moldavian, monitor,
# Nearest to th: nd, century, legalization, earliest, preslav, history, mauryan, arsacid,
# Nearest to on: the, news, joaquim, s, massively, asis, prayers, ap,
# Nearest to governor: lieutenant, liam, reserve, pluriform, reductions, hale, pius, snegur,
# Nearest to operations: marrakech, operation, general, eclipse, supervision, siddeley, thus, stabilized,
# Nearest to assembly: constituents, pluriform, elected, bicameral, constituencies, taoiseach, languedoc, legislative,
# Nearest to gold: metals, item, titanium, olbers, precipitates, tin, feathers, strictest,
# Nearest to channel: channels, sledge, widebody, telegram, bbc, capitalised, estonia, knowbot,
# Nearest to issue: microeconomic, ameliorated, dlp, undone, moulton, colonialism, feist, sergius,
# Nearest to operating: vcs, minix, unix, outselling, competitors, swivel, drivers, disk,
# Nearest to bill: punched, maleficarum, statutes, nutrition, andrew, intelligent, awaits, ethicists,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9814 0.3579 sec/batch
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8528 0.3501 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8691 0.3278 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8282 0.3654 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8588 0.3462 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8975 0.3693 sec/batch
# Nearest to and: the, of, in, to, by, are, with, a,
# Nearest to over: considerably, were, undercoat, attained, six, adr, zero, live,
# Nearest to when: would, breaks, so, interrupted, to, castillian, preceded, cursive,
# Nearest to more: than, less, have, for, mechanized, and, tendency, strategies,
# Nearest to have: are, some, other, been, has, these, now, and,
# Nearest to into: soul, the, in, condensed, divided, complete, struggling, apart,
# Nearest to th: century, nd, centuries, history, york, earliest, angolan, legalization,
# Nearest to on: the, s, for, a, of, by, in, from,
# Nearest to governor: lieutenant, reserve, adirondack, pluriform, heinlein, popularised, partements, hale,
# Nearest to operations: operation, marrakech, supervision, eclipse, multiplication, siddeley, cascavel, halfbakery,
# Nearest to assembly: constituents, frontman, gaspar, plans, selassie, aphra, taoiseach, garten,
# Nearest to gold: titanium, item, metals, silver, olbers, prizes, precipitates, medals,
# Nearest to channel: channels, upn, wb, aired, fjord, bros, tv, estonia,
# Nearest to issue: marvel, undone, excessively, transputer, centripetal, delved, kryptonite, brainiac,
# Nearest to operating: minix, unix, outselling, whale, vcs, razed, rsts, systems,
# Nearest to bill: punched, statutes, passed, maleficarum, nutrition, truest, worse, nrc,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8292 0.3442 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8456 0.3460 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8623 0.3336 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8528 0.3366 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8667 0.3698 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9122 0.3839 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8808 0.3343 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8401 0.3265 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8782 0.3283 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8400 0.3431 sec/batch
# Nearest to and: the, in, of, to, by, with, a, see,
# Nearest to over: zero, considerably, six, attained, years, total, rcaf, were,
# Nearest to when: castillian, interrupted, breaks, would, so, to, deserving, lessened,
# Nearest to more: than, less, and, became, have, for, mechanized, of,
# Nearest to have: are, some, other, been, has, non, now, even,
# Nearest to into: the, soul, in, divided, condensed, stijl, during, apart,
# Nearest to th: century, nd, centuries, late, history, earliest, four, in,
# Nearest to on: the, by, s, of, for, a, an, in,
# Nearest to governor: lieutenant, reserve, adirondack, heinlein, popularised, hale, astronomer, partements,
# Nearest to operations: operation, marrakech, multiplication, supervision, eclipse, siddeley, halfbakery, ribbentrop,
# Nearest to assembly: constituents, frontman, plans, taoiseach, selassie, gaspar, aphra, bcp,
# Nearest to gold: titanium, item, metals, silver, prizes, olbers, medals, medal,
# Nearest to channel: channels, upn, fjord, wb, estonia, aired, bros, regulus,
# Nearest to issue: marvel, undone, transputer, excessively, centripetal, protect, curdled, ameliorated,
# Nearest to operating: minix, unix, outselling, whale, vcs, razed, rsts, observant,
# Nearest to bill: punched, statutes, passed, worse, maleficarum, unconstitutional, nutrition, truest,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8537 0.3587 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8574 0.3491 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8185 0.3579 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8574 0.3407 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9026 0.3583 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8410 0.3568 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9590 0.3486 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8779 0.3349 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9324 0.3503 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8393 0.3330 sec/batch
# Nearest to and: the, of, in, to, by, with, a, see,
# Nearest to over: zero, six, were, attained, considerably, rcaf, in, adr,
# Nearest to when: would, so, nader, castillian, preceded, interrupted, breaks, grady,
# Nearest to more: than, less, have, these, mechanized, for, scheme, tendency,
# Nearest to have: are, some, other, been, has, non, now, these,
# Nearest to into: soul, condensed, the, in, divided, muzzleloaders, cienfuegos, ainu,
# Nearest to th: century, nd, centuries, history, late, earliest, four, preslav,
# Nearest to on: the, by, of, s, for, a, in, from,
# Nearest to governor: lieutenant, adirondack, heinlein, astronomer, hale, reserve, popularised, geer,
# Nearest to operations: operation, marrakech, supervision, multiplication, eclipse, siddeley, ribbentrop, stabilized,
# Nearest to assembly: constituents, plans, frontman, selassie, gaspar, taoiseach, aphra, bcp,
# Nearest to gold: item, silver, titanium, metals, medals, prizes, olbers, medal,
# Nearest to channel: channels, upn, fjord, wb, bros, estonia, regulus, aired,
# Nearest to issue: marvel, undone, transputer, excessively, centripetal, protect, curdled, macmillan,
# Nearest to operating: minix, unix, whale, outselling, vcs, rsts, razed, observant,
# Nearest to bill: punched, statutes, passed, maleficarum, unconstitutional, nutrition, worse, truest,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7757 0.3583 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8713 0.3539 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7928 0.3487 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8988 0.3832 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8588 0.3399 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8521 0.3608 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9226 0.1679 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8080 0.3359 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8388 0.3490 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8250 0.3383 sec/batch
# Nearest to and: of, the, in, to, by, a, with, are,
# Nearest to over: six, attained, rcaf, zero, considerably, live, oint, adr,
# Nearest to when: so, interrupted, would, castillian, was, preceded, breaks, to,
# Nearest to more: than, less, these, have, for, scheme, largely, tendency,
# Nearest to have: are, some, other, been, has, now, these, and,
# Nearest to into: soul, condensed, apart, muzzleloaders, divided, stijl, the, cienfuegos,
# Nearest to th: century, nd, centuries, history, earliest, late, four, angolan,
# Nearest to on: the, of, by, s, a, in, for, from,
# Nearest to governor: lieutenant, astronomer, adirondack, heinlein, popularised, hale, reserve, geer,
# Nearest to operations: operation, marrakech, multiplication, supervision, eclipse, siddeley, cascavel, tree,
# Nearest to assembly: constituents, plans, frontman, aphra, bogor, selassie, avodah, gaspar,
# Nearest to gold: titanium, item, silver, prizes, medals, olbers, metals, medal,
# Nearest to channel: channels, upn, wb, fjord, bros, estonia, sledge, regulus,
# Nearest to issue: undone, excessively, transputer, marvel, centripetal, curdled, dlp, brainiac,
# Nearest to operating: minix, unix, vcs, whale, outselling, razed, systems, system,
# Nearest to bill: punched, statutes, passed, maleficarum, nutrition, worse, expansionist, unconstitutional,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8108 0.3454 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8361 0.3750 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8262 0.3567 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7925 0.3629 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8467 0.3502 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8218 0.3405 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8662 0.3416 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7375 0.3360 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7992 0.3336 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8093 0.3419 sec/batch
# Nearest to and: the, of, in, to, are, with, a, by,
# Nearest to over: zero, six, considerably, live, attained, years, moldavia, total,
# Nearest to when: so, would, preceded, was, interrupted, breaks, jtf, finally,
# Nearest to more: than, less, have, these, of, for, scheme, tendency,
# Nearest to have: are, some, other, been, has, these, now, more,
# Nearest to into: condensed, soul, the, stijl, apart, divided, during, muzzleloaders,
# Nearest to th: century, nd, centuries, late, history, earliest, angolan, four,
# Nearest to on: the, of, s, a, by, for, an, in,
# Nearest to governor: lieutenant, adirondack, heinlein, astronomer, popularised, reserve, geer, hale,
# Nearest to operations: operation, marrakech, supervision, multiplication, eclipse, tree, siddeley, thus,
# Nearest to assembly: constituents, frontman, plans, aphra, gaspar, selassie, bogor, bcp,
# Nearest to gold: titanium, item, silver, prizes, medals, metals, olbers, medal,
# Nearest to channel: channels, upn, wb, fjord, aired, bros, news, estonia,
# Nearest to issue: excessively, undone, marvel, transputer, centripetal, curdled, dlp, delved,
# Nearest to operating: minix, unix, vcs, whale, outselling, systems, razed, system,
# Nearest to bill: punched, passed, statutes, nutrition, maleficarum, worse, truest, maw,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7540 0.3303 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8099 0.3714 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8574 0.3642 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8115 0.3455 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7959 0.3418 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8884 0.3621 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8337 0.3491 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8202 0.3430 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8174 0.3414 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8460 0.3270 sec/batch
# Nearest to and: of, the, in, to, with, see, a, are,
# Nearest to over: considerably, zero, oint, total, moldavia, attained, in, lnot,
# Nearest to when: breaks, so, would, interrupted, preceded, macron, jtf, time,
# Nearest to more: than, less, these, have, for, and, largely, least,
# Nearest to have: are, some, other, been, has, these, non, now,
# Nearest to into: soul, the, condensed, divided, in, muzzleloaders, stijl, exerts,
# Nearest to th: century, nd, centuries, late, angolan, history, four, preslav,
# Nearest to on: the, of, a, s, for, by, in, from,
# Nearest to governor: lieutenant, adirondack, heinlein, reserve, astronomer, geer, partements, popularised,
# Nearest to operations: operation, supervision, marrakech, eclipse, multiplication, tree, cascavel, halfbakery,
# Nearest to assembly: constituents, frontman, plans, selassie, aphra, bogor, bcp, gaspar,
# Nearest to gold: titanium, item, silver, prizes, medals, olbers, medal, metals,
# Nearest to channel: channels, upn, aired, wb, fjord, bros, weekly, tv,
# Nearest to issue: undone, excessively, marvel, centripetal, transputer, delved, brainiac, dlp,
# Nearest to operating: minix, unix, vcs, whale, outselling, razed, observant, systems,
# Nearest to bill: punched, statutes, worse, passed, maleficarum, nutrition, truest, discriminatory,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8949 0.3273 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8374 0.3274 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8111 0.3767 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8419 0.3351 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8770 0.3392 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8563 0.3254 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8215 0.3278 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8327 0.3540 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7929 0.3440 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7992 0.3644 sec/batch
# Nearest to and: of, in, the, to, with, a, are, by,
# Nearest to over: in, zero, all, six, were, and, live, one,
# Nearest to when: to, so, would, time, breaks, interrupted, was, preceded,
# Nearest to more: than, less, have, these, and, of, for, became,
# Nearest to have: are, some, other, been, has, non, and, these,
# Nearest to into: the, in, soul, muzzleloaders, divided, condensed, around, apart,
# Nearest to th: century, nd, centuries, late, earliest, seven, history, four,
# Nearest to on: the, of, a, s, for, by, in, from,
# Nearest to governor: lieutenant, adirondack, heinlein, reserve, popularised, geer, partements, hale,
# Nearest to operations: operation, supervision, marrakech, eclipse, tree, multiplication, thus, arithmetical,
# Nearest to assembly: constituents, frontman, plans, selassie, aphra, bcp, aristides, excessively,
# Nearest to gold: titanium, silver, item, prizes, medals, medal, metals, uranium,
# Nearest to channel: channels, upn, wb, fjord, aired, weekly, tv, news,
# Nearest to issue: excessively, undone, marvel, transputer, bittorrent, centripetal, curdled, brainiac,
# Nearest to operating: minix, unix, vcs, whale, outselling, razed, boar, observant,
# Nearest to bill: punched, passed, statutes, worse, nutrition, maleficarum, expansionist, discriminatory,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8687 0.3489 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8055 0.3556 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9208 0.3404 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8872 0.3604 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8922 0.3308 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8660 0.3250 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7977 0.3220 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8371 0.3450 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7394 0.3298 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8690 0.3334 sec/batch
# Nearest to and: in, the, of, to, by, with, are, a,
# Nearest to over: in, zero, live, six, considerably, total, all, were,
# Nearest to when: was, would, so, preceded, to, bulb, jtf, breaks,
# Nearest to more: than, less, these, have, for, of, and, became,
# Nearest to have: are, some, other, has, been, now, non, these,
# Nearest to into: the, condensed, in, muzzleloaders, divided, soul, debate, ainu,
# Nearest to th: century, nd, centuries, late, history, earliest, angolan, st,
# Nearest to on: the, s, for, a, of, in, by, however,
# Nearest to governor: lieutenant, adirondack, heinlein, astronomer, popularised, reductions, geer, reserve,
# Nearest to operations: operation, marrakech, supervision, multiplication, tree, eclipse, arithmetical, halfbakery,
# Nearest to assembly: constituents, plans, frontman, selassie, aphra, bcp, bogor, excessively,
# Nearest to gold: titanium, silver, item, prizes, medal, medalist, medals, feathers,
# Nearest to channel: channels, upn, wb, fjord, weekly, news, aired, estonia,
# Nearest to issue: undone, excessively, marvel, transputer, centripetal, brainiac, curdled, bittorrent,
# Nearest to operating: minix, unix, vcs, whale, outselling, system, razed, boar,
# Nearest to bill: punched, passed, statutes, worse, maleficarum, expansionist, nutrition, boston,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8284 0.3340 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8448 0.3316 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
